# %%
from crewai import LLM, Agent, Crew, Process, Task
from crewai_tools import (
    DirectoryReadTool,
    FileReadTool
    # WebsiteSearchTool
)
import os
from dotenv import load_dotenv
import yaml

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Description:
#
# CrewAI output with proper project folder structure, using DirectoryReadTool
#
# Upgrade model used to paid for better performance
#
# Resolved token limit to avoid truncating output
#
# Strict prompt instruction to make sure no DocStrings included in output
#
# Stricter temperature / top_p to reduce creativity

# %%
# Setup LLM from OpenRouter

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
model_name = "openrouter/x-ai/grok-4.1-fast"

llm = LLM(
    model=model_name,
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
    max_tokens=16000,
    max_completion_tokens=16000,
    temperature=0.3,
    top_p=0.9
)

# %%
# List of Tools

directory_tool = DirectoryReadTool()
file_tool = FileReadTool()

# %%
# Setup config for agents and tasks

agents_config = "agents.yaml"
with open(agents_config, "r", encoding="utf-8") as f:
    agents_config = yaml.safe_load(f)

tasks_config = "tasks.yaml"
with open(tasks_config, "r", encoding="utf-8") as f:
    tasks_config = yaml.safe_load(f)

# %%
# List of Agents

coder_agent = Agent(
    config=agents_config["coder"],
    verbose=True,
    tools=[file_tool, directory_tool],
    llm=llm
)

# %%
# List of Tasks

task = Task(
    config=tasks_config["create_webapp"],
    agent=coder_agent
)

# %%
# Init Crew and run Process

crew = Crew(
    agents=[coder_agent],
    tasks=[task],
    process=Process.sequential,
    verbose=True,
    tracing=True
)

# %%
# Testing Crew

user_request = """
    Create a simple single-file web app that displays 'Hello, World!' 
    and has a button to toggle dark mode.
"""

result = crew.kickoff(
    inputs={
        "user_request": user_request,
        "project_name": "hello_world_webapp"
    }
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 49c52f13-1532-421d-a7c5-859951440d83                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %%
def print_token_usage(result, crew=None, prompt_cost_per_million=0.2, completion_cost_per_million=0.5):
    """Pretty print token usage after crew finishes"""
    print("\n" + "="*70)
    print("CREW FINISHED - TOKEN USAGE REPORT")
    print("="*70)
    
    tu = result.token_usage
    
    print(f"Model Used         : {model_name}")
    print(f"Total Tokens       : {getattr(tu, 'total_tokens', 'N/A'):,}")
    print(f"Prompt Tokens      : {getattr(tu, 'prompt_tokens', 'N/A'):,}")
    print(f"Completion Tokens  : {getattr(tu, 'completion_tokens', 'N/A'):,}")
    print(f"Successful Requests: {getattr(tu, 'successful_requests', 'N/A')}")
    
    # Rough cost estimation
    if hasattr(tu, 'total_tokens'):
        prompt_cost = (getattr(tu, 'prompt_tokens', 0) / 1_000_000) * prompt_cost_per_million
        completion_cost = (getattr(tu, 'completion_tokens', 0) / 1_000_000) * completion_cost_per_million
        print(f"\nEstimated Prompt Cost     : ~${prompt_cost:.4f} USD")
        print(f"Estimated Completion Cost : ~${completion_cost:.4f} USD")
        print(f"Estimated Total Cost     : ~${prompt_cost + completion_cost:.4f} USD")
    
    if crew and hasattr(crew, 'usage_metrics'):
        print(f"\nRaw Usage Metrics: {crew.usage_metrics}")

print_token_usage(result, crew, prompt_cost_per_million=0.2, completion_cost_per_million=0.5)
# Out:
# ...
# CREW FINISHED - TOKEN USAGE REPORT
# ...
# Model Used         : openrouter/x-ai/grok-4.1-fast
# Total Tokens       : 3,994
# Prompt Tokens      : 855
# Completion Tokens  : 3,139
# Successful Requests: 1
#
# Estimated Prompt Cost     : ~$0.0002 USD
# Estimated Completion Cost : ~$0.0016 USD
# Estimated Total Cost     : ~$0.0017 USD
#
# Raw Usage Metrics: total_tokens=3994 prompt_tokens=855 cached_prompt_tokens=149 completion_tokens=3139 successful_requests=1

# %%
# Testing Crew

user_request = """
    Create a functional to-do list web app with the following features:
- Add, edit, and delete tasks
- Mark tasks as completed
- Filter tasks by status (all, active, completed)
"""

result = crew.kickoff(
    inputs={
        "user_request": user_request,
        "project_name": "todo_list_webapp"
    }
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3eb8d19b-2bd7-47f7-b03e-3cf3c20cb535                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %%
print_token_usage(result, crew, prompt_cost_per_million=0.2, completion_cost_per_million=0.5)
# Out:
# ...
# CREW FINISHED - TOKEN USAGE REPORT
# ...
# Model Used         : openrouter/x-ai/grok-4.1-fast
# Total Tokens       : 12,314
# Prompt Tokens      : 2,753
# Completion Tokens  : 9,561
# Successful Requests: 2
#
# Estimated Prompt Cost     : ~$0.0006 USD
# Estimated Completion Cost : ~$0.0048 USD
# Estimated Total Cost     : ~$0.0053 USD
#
# Raw Usage Metrics: total_tokens=12314 prompt_tokens=2753 cached_prompt_tokens=298 completion_tokens=9561 successful_requests=2
