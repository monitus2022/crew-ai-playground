# %%
from crewai import LLM, Agent, Crew, Process, Task
from crewai_tools import (
    DirectoryReadTool,
    FileReadTool
    # WebsiteSearchTool
)
import os
from dotenv import load_dotenv
import yaml

load_dotenv()
# Out:
# True

# %%
# Setup LLM from OpenRouter

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

llm = LLM(
    model="openrouter/openai/gpt-oss-120b:free",
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
    max_tokens=16000
)

# %%
# List of Tools

directory_tool = DirectoryReadTool()
file_tool = FileReadTool()

# %%
# Setup config for agents and tasks

agents_config = "config/coder_agent_only.yaml"
with open(agents_config, "r", encoding="utf-8") as f:
    agents_config = yaml.safe_load(f)

tasks_config = "config/coder_task_only.yaml"
with open(tasks_config, "r", encoding="utf-8") as f:
    tasks_config = yaml.safe_load(f)

# %%
# List of Agents

coder_agent = Agent(
    config=agents_config["coder"],
    verbose=True,
    tools=[file_tool],
    llm=llm
)

# %%
# List of Tasks

task = Task(
    config=tasks_config["create_webapp"],
    agent=coder_agent
)

# %%
# Init Crew and run Process

crew = Crew(
    agents=[coder_agent],
    tasks=[task],
    process=Process.sequential,
    verbose=True,
    tracing=True
)

# %%
# Testing Crew

user_request = "Create a simple single-file web app that displays 'Hello, World!' and has a button to toggle dark mode."

result = crew.kickoff(
    inputs={"user_request": user_request}
)

result
# Out:
# ╭──────────────────────────────────────────────── Yanked Version ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Version 1.14.1 has been yanked from PyPI.                                                                      │
# │  Reason: Error on dependency with anthropic                                                                     │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: e7217324-496c-442e-9244-9869363135b3                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Create a complete single-file web application for the following user request:                            │
# │  Create a simple single-file web app that displays 'Hello, World!' and has a button to toggle dark mode.        │
# │                                                                                                                 │
# │  Important Requirements:                                                                                        │
# │  - Use only one HTML file (single file app)                                                                     │
# │  - Include Tailwind CSS via CDN                                                                                 │
# │  - Make it beautiful, modern, and visually appealing                                                            │
# │  - Add smooth animations where suitable                                                                         │
# │  - Make it fully functional with JavaScript                                                                     │
# │  - Ensure it is mobile responsive                                                                               │
# │  - Add a dark mode toggle if it makes sense for the app                                                         │
# │                                                                                                                 │
# │  ID: 536cb0bb-c705-479a-b3cc-7ba88518d22f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Frontend Web Developer                                                                           │
# │                                                                                                                 │
# │  Task: Create a complete single-file web application for the following user request:                            │
# │  Create a simple single-file web app that displays 'Hello, World!' and has a button to toggle dark mode.        │
# │                                                                                                                 │
# │  Important Requirements:                                                                                        │
# │  - Use only one HTML file (single file app)                                                                     │
# │  - Include Tailwind CSS via CDN                                                                                 │
# │  - Make it beautiful, modern, and visually appealing                                                            │
# │  - Add smooth animations where suitable                                                                         │
# │  - Make it fully functional with JavaScript                                                                     │
# │  - Ensure it is mobile responsive                                                                               │
# │  - Add a dark mode toggle if it makes sense for the app                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Frontend Web Developer                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  <!DOCTYPE html>                                                                                                │
# │  <html lang="en" class="scroll-smooth">                                                                         │
# │  <head>                                                                                                         │
# │    <meta charset="UTF-8">                                                                                       │
# │    <meta name="viewport" content="width=device-width, initial-scale=1.0">                                       │
# │    <title>Hello World - Dark Mode Toggle</title>                                                                │
# │    <script src="https://cdn.tailwindcss.com"></script>                                                          │
# │    <script>                                                                                                     │
# │      // Tailwind config for dark mode based on class                                                            │
# │      tailwind.config = {                                                                                        │
# │        darkMode: 'class',                                                                                       │
# │        theme: {                                                                                                 │
# │          extend: {                                                                                              │
# │            animation: {                                                                                         │
# │              fade: 'fadeOut 0.5s ease-out forwards',                                                            │
# │              bounce: 'bounce 0.6s infinite',                                                                    │
# │            },                                                                                                   │
# │            keyframes: {                                                                                         │
# │              fadeOut: {                                                                                         │
# │                '0%': { opacity: '1' },                                                                          │
# │                '100%': { opacity: '0' },                                                                        │
# │              },                                                                                                 │
# │              bounce: {                                                                                          │
# │                '0%, 100%': { transform: 'translateY(-25%)', animationTimingFunction: 'cubic-bezier(0.8,0,1,1)'  │
# │  },                                                                                                             │
# │                '50%': { transform: 'none', animationTimingFunction: 'cubic-bezier(0,0,0.2,1)' },                │
# │              },                                                                                                 │
# │            },                                                                                                   │
# │          },                                                                                                     │
# │        },                                                                                                       │
# │      };                                                                                                         │
# │    </script>                                                                                                    │
# │    <style>                                                                                                      │
# │      .toggle-thumb {                                                                                            │
# │        transition: transform 0.3s ease;                                                                         │
# │      }                                                                                                          │
# │      .toggle-checkbox:checked ~ .toggle-thumb {                                                                 │
# │        transform: translateX(1.5rem);                                                                           │
# │      }                                                                                                          │
# │    </style>                                                                                                     │
# │  </head>                                                                                                        │
# │  <body class="bg-gray-100 dark:bg-gray-900 text-gray-900 dark:text-gray-100 flex items-center justify-center    │
# │  min-h-screen transition-colors duration-300">                                                                  │
# │    <div class="text-center space-y-8 p-6">                                                                      │
# │      <h1 class="text-4xl md:text-5xl font-extrabold tracking-wide animate-bounce">Hello, World!</h1>            │
# │      <button id="darkModeToggle" class="flex items-center mx-auto px-4 py-2 bg-indigo-600 hover:bg-indigo-700   │
# │  dark:bg-indigo-500 dark:hover:bg-indigo-600 text-white rounded-full focus:outline-none focus:ring-2            │
# │  focus:ring-indigo-300 transition-colors duration-200">                                                         │
# │        <span class="mr-2">Toggle Dark Mode</span>                                                               │
# │        <svg class="w-5 h-5" fill="none" stroke="currentColor" viewBox="0 0 24 24">                              │
# │          <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2"                                  │
# │            d="M12 3v1m0 16v1m8.66-12.34l-.71.71M5.05 18.95l-.71.71M21 12h-1M4 12H3m15.66 4.66l-.71-.71M5.05     │
# │  5.05l-.71-.71M12 5a7 7 0 100 14 7 7 0 000-14z"/>                                                               │
# │        </svg>                                                                                                   │
# │      </button>                                                                                                  │
# │      <label class="inline-flex items-center cursor-pointer">                                                    │
# │        <input type="checkbox" id="themeSwitch" class="sr-only toggle-checkbox">                                 │
# │        <div class="w-12 h-6 bg-gray-300 dark:bg-gray-600 rounded-full relative">                                │
# │          <div class="toggle-thumb absolute left-0 top-0 w-6 h-6 bg-white dark:bg-gray-200 rounded-full shadow   │
# │  transform"></div>                                                                                              │
# │        </div>                                                                                                   │
# │      </label>                                                                                                   │
# │    </div>                                                                                                       │
# │    <script>                                                                                                     │
# │      const themeSwitch = document.getElementById('themeSwitch');                                                │
# │      const root = document.documentElement;                                                                     │
# │                                                                                                                 │
# │      const setTheme = (dark) => {                                                                               │
# │        if (dark) {                                                                                              │
# │          root.classList.add('dark');                                                                            │
# │          localStorage.setItem('theme', 'dark');                                                                 │
# │        } else {                                                                                                 │
# │          root.classList.remove('dark');                                                                         │
# │          localStorage.setItem('theme', 'light');                                                                │
# │        }                                                                                                        │
# │      };                                                                                                         │
# │                                                                                                                 │
# │      // Initialize theme from storage or system preference                                                      │
# │      const savedTheme = localStorage.getItem('theme');                                                          │
# │      if (savedTheme) {                                                                                          │
# │        setTheme(savedTheme === 'dark');                                                                         │
# │        themeSwitch.checked = savedTheme === 'dark';                                                             │
# │      } else {                                                                                                   │
# │        const prefersDark = window.matchMedia('(prefers-color-scheme: dark)').matches;                           │
# │        setTheme(prefersDark);                                                                                   │
# │        themeSwitch.checked = prefersDark;                                                                       │
# │      }                                                                                                          │
# │                                                                                                                 │
# │      themeSwitch.addEventListener('change', () => setTheme(themeSwitch.checked));                               │
# │      document.getElementById('darkModeToggle').addEventListener('click', () => {                                │
# │        themeSwitch.checked = !themeSwitch.checked;                                                              │
# │        setTheme(themeSwitch.checked);                                                                           │
# │      });                                                                                                        │
# │    </script>                                                                                                    │
# │  </body>                                                                                                        │
# │  </html>                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Create a complete single-file web application for the following user request:                            │
# │  Create a simple single-file web app that displays 'Hello, World!' and has a button to toggle dark mode.        │
# │                                                                                                                 │
# │  Important Requirements:                                                                                        │
# │  - Use only one HTML file (single file app)                                                                     │
# │  - Include Tailwind CSS via CDN                                                                                 │
# │  - Make it beautiful, modern, and visually appealing                                                            │
# │  - Add smooth animations where suitable                                                                         │
# │  - Make it fully functional with JavaScript                                                                     │
# │  - Ensure it is mobile responsive                                                                               │
# │  - Add a dark mode toggle if it makes sense for the app                                                         │
# │                                                                                                                 │
# │  Agent: Expert Frontend Web Developer                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='<!DOCTYPE html>\n<html lang="en" class="scroll-smooth">\n<head>\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <title>Hello World - Dark Mode Toggle</title>\n  <script src="https://cdn.tailwindcss.com"></script>\n  <script>\n    // Tailwind config for dark mode based on class\n    tailwind.config = {\n      darkMode: \'class\',\n      theme: {\n        extend: {\n          animation: {\n            fade: \'fadeOut 0.5s ease-out forwards\',\n            bounce: \'bounce 0.6s infinite\',\n          },\n          keyframes: {\n            fadeOut: {\n              \'0%\': { opacity: \'1\' },\n              \'100%\': { opacity: \'0\' },\n            },\n            bounce: {\n              \'0%, 100%\': { transform: \'translateY(-25%)\', animationTimingFunction: \'cubic-bezier(0.8,0,1,1)\' },\n              \'50%\': { transform: \'none\', animationTimingFunction: \'cubic-bezier(0,0,0.2,1)\' },\n            },\n          },\n        },\n      },\n    };\n  </script>\n  <style>\n    .toggle-thumb {\n      transition: transform 0.3s ease;\n    }\n    .toggle-checkbox:checked ~ .toggle-thumb {\n      transform: translateX(1.5rem);\n    }\n  </style>\n</head>\n<body class="bg-gray-100 dark:bg-gray-900 text-gray-900 dark:text-gray-100 flex items-center justify-center min-h-screen transition-colors duration-300">\n  <div class="text-center space-y-8 p-6">\n    <h1 class="text-4xl md:text-5xl font-extrabold tracking-wide animate-bounce">Hello, World!</h1>\n    <button id="darkModeToggle" class="flex items-center mx-auto px-4 py-2 bg-indigo-600 hover:bg-indigo-700 dark:bg-indigo-500 dark:hover:bg-indigo-600 text-white rounded-full focus:outline-none focus:ring-2 focus:ring-indigo-300 transition-colors duration-200">\n      <span class="mr-2">Toggle Dark Mode</span>\n      <svg class="w-5 h-5" fill="none" stroke="currentColor" viewBox="0 0 24 24">\n        <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2"\n          d="M12 3v1m0 16v1m8.66-12.34l-.71.71M5.05 18.95l-.71.71M21 12h-1M4 12H3m15.66 4.66l-.71-.71M5.05 5.05l-.71-.71M12 5a7 7 0 100 14 7 7 0 000-14z"/>\n      </svg>\n    </button>\n    <label class="inline-flex items-center cursor-pointer">\n      <input type="checkbox" id="themeSwitch" class="sr-only toggle-checkbox">\n      <div class="w-12 h-6 bg-gray-300 dark:bg-gray-600 rounded-full relative">\n        <div class="toggle-thumb absolute left-0 top-0 w-6 h-6 bg-white dark:bg-gray-200 rounded-full shadow transform"></div>\n      </div>\n    </label>\n  </div>\n  <script>\n    const themeSwitch = document.getElementById(\'themeSwitch\');\n    const root = document.documentElement;\n\n    const setTheme = (dark) => {\n      if (dark) {\n        root.classList.add(\'dark\');\n        localStorage.setItem(\'theme\', \'dark\');\n      } else {\n        root.classList.remove(\'dark\');\n        localStorage.setItem(\'theme\', \'light\');\n      }\n    };\n\n    // Initialize theme from storage or system preference\n    const savedTheme = localStorage.getItem(\'theme\');\n    if (savedTheme) {\n      setTheme(savedTheme === \'dark\');\n      themeSwitch.checked = savedTheme === \'dark\';\n    } else {\n      const prefersDark = window.matchMedia(\'(prefers-color-scheme: dark)\').matches;\n      setTheme(prefersDark);\n      themeSwitch.checked = prefersDark;\n    }\n\n    themeSwitch.addEventListener(\'change\', () => setTheme(themeSwitch.checked));\n    document.getElementById(\'darkModeToggle\').addEventListener(\'click\', () => {\n      themeSwitch.checked = !themeSwitch.checked;\n      setTheme(themeSwitch.checked);\n    });\n  </script>\n</body>\n</html>', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description="Create a complete single-file web application for the following user request:\nCreate a simple single-file web app that displays 'Hello, World!' and has a button to toggle dark mode.\n\nImportant Requirements:\n- Use only o ...
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: e7217324-496c-442e-9244-9869363135b3                                                                       │
# │  Final Output: <!DOCTYPE html>                                                                                  │
# │  <html lang="en" class="scroll-smooth">                                                                         │
# │  <head>                                                                                                         │
# │    <meta charset="UTF-8">                                                                                       │
# │    <meta name="viewport" content="width=device-width, initial-scale=1.0">                                       │
# │    <title>Hello World - Dark Mode Toggle</title>                                                                │
# │    <script src="https://cdn.tailwindcss.com"></script>                                                          │
# │    <script>                                                                                                     │
# │      // Tailwind config for dark mode based on class                                                            │
# │      tailwind.config = {                                                                                        │
# │        darkMode: 'class',                                                                                       │
# │        theme: {                                                                                                 │
# │          extend: {                                                                                              │
# │            animation: {                                                                                         │
# │              fade: 'fadeOut 0.5s ease-out forwards',                                                            │
# │              bounce: 'bounce 0.6s infinite',                                                                    │
# │            },                                                                                                   │
# │            keyframes: {                                                                                         │
# │              fadeOut: {                                                                                         │
# │                '0%': { opacity: '1' },                                                                          │
# │                '100%': { opacity: '0' },                                                                        │
# │              },                                                                                                 │
# │              bounce: {                                                                                          │
# │                '0%, 100%': { transform: 'translateY(-25%)', animationTimingFunction: 'cubic-bezier(0.8,0,1,1)'  │
# │  },                                                                                                             │
# │                '50%': { transform: 'none', animationTimingFunction: 'cubic-bezier(0,0,0.2,1)' },                │
# │              },                                                                                                 │
# │            },                                                                                                   │
# │          },                                                                                                     │
# │        },                                                                                                       │
# │      };                                                                                                         │
# │    </script>                                                                                                    │
# │    <style>                                                                                                      │
# │      .toggle-thumb {                                                                                            │
# │        transition: transform 0.3s ease;                                                                         │
# │      }                                                                                                          │
# │      .toggle-checkbox:checked ~ .toggle-thumb {                                                                 │
# │        transform: translateX(1.5rem);                                                                           │
# │      }                                                                                                          │
# │    </style>                                                                                                     │
# │  </head>                                                                                                        │
# │  <body class="bg-gray-100 dark:bg-gray-900 text-gray-900 dark:text-gray-100 flex items-center justify-center    │
# │  min-h-screen transition-colors duration-300">                                                                  │
# │    <div class="text-center space-y-8 p-6">                                                                      │
# │      <h1 class="text-4xl md:text-5xl font-extrabold tracking-wide animate-bounce">Hello, World!</h1>            │
# │      <button id="darkModeToggle" class="flex items-center mx-auto px-4 py-2 bg-indigo-600 hover:bg-indigo-700   │
# │  dark:bg-indigo-500 dark:hover:bg-indigo-600 text-white rounded-full focus:outline-none focus:ring-2            │
# │  focus:ring-indigo-300 transition-colors duration-200">                                                         │
# │        <span class="mr-2">Toggle Dark Mode</span>                                                               │
# │        <svg class="w-5 h-5" fill="none" stroke="currentColor" viewBox="0 0 24 24">                              │
# │          <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2"                                  │
# │            d="M12 3v1m0 16v1m8.66-12.34l-.71.71M5.05 18.95l-.71.71M21 12h-1M4 12H3m15.66 4.66l-.71-.71M5.05     │
# │  5.05l-.71-.71M12 5a7 7 0 100 14 7 7 0 000-14z"/>                                                               │
# │        </svg>                                                                                                   │
# │      </button>                                                                                                  │
# │      <label class="inline-flex items-center cursor-pointer">                                                    │
# │        <input type="checkbox" id="themeSwitch" class="sr-only toggle-checkbox">                                 │
# │        <div class="w-12 h-6 bg-gray-300 dark:bg-gray-600 rounded-full relative">                                │
# │          <div class="toggle-thumb absolute left-0 top-0 w-6 h-6 bg-white dark:bg-gray-200 rounded-full shadow   │
# │  transform"></div>                                                                                              │
# │        </div>                                                                                                   │
# │      </label>                                                                                                   │
# │    </div>                                                                                                       │
# │    <script>                                                                                                     │
# │      const themeSwitch = document.getElementById('themeSwitch');                                                │
# │      const root = document.documentElement;                                                                     │
# │                                                                                                                 │
# │      const setTheme = (dark) => {                                                                               │
# │        if (dark) {                                                                                              │
# │          root.classList.add('dark');                                                                            │
# │          localStorage.setItem('theme', 'dark');                                                                 │
# │        } else {                                                                                                 │
# │          root.classList.remove('dark');                                                                         │
# │          localStorage.setItem('theme', 'light');                                                                │
# │        }                                                                                                        │
# │      };                                                                                                         │
# │                                                                                                                 │
# │      // Initialize theme from storage or system preference                                                      │
# │      const savedTheme = localStorage.getItem('theme');                                                          │
# │      if (savedTheme) {                                                                                          │
# │        setTheme(savedTheme === 'dark');                                                                         │
# │        themeSwitch.checked = savedTheme === 'dark';                                                             │
# │      } else {                                                                                                   │
# │        const prefersDark = window.matchMedia('(prefers-color-scheme: dark)').matches;                           │
# │        setTheme(prefersDark);                                                                                   │
# │        themeSwitch.checked = prefersDark;                                                                       │
# │      }                                                                                                          │
# │                                                                                                                 │
# │      themeSwitch.addEventListener('change', () => setTheme(themeSwitch.checked));                               │
# │      document.getElementById('darkModeToggle').addEventListener('click', () => {                                │
# │        themeSwitch.checked = !themeSwitch.checked;                                                              │
# │        setTheme(themeSwitch.checked);                                                                           │
# │      });                                                                                                        │
# │    </script>                                                                                                    │
# │  </body>                                                                                                        │
# │  </html>                                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
def print_token_usage(result, crew=None):
    """Pretty print token usage after crew finishes"""
    print("\n" + "="*70)
    print("CREW FINISHED - TOKEN USAGE REPORT")
    print("="*70)
    
    tu = result.token_usage
    
    print(f"Total Tokens       : {getattr(tu, 'total_tokens', 'N/A'):,}")
    print(f"Prompt Tokens      : {getattr(tu, 'prompt_tokens', 'N/A'):,}")
    print(f"Completion Tokens  : {getattr(tu, 'completion_tokens', 'N/A'):,}")
    print(f"Successful Requests: {getattr(tu, 'successful_requests', 'N/A')}")
    
    # Rough cost estimation (Claude 3.5 Sonnet on OpenRouter)
    if hasattr(tu, 'total_tokens'):
        estimated_cost = (tu.total_tokens / 1_000_000) * 3.0   # ~$3 per million tokens for Claude 3.5 Sonnet
        print(f"Estimated Cost     : ~${estimated_cost:.4f} USD")
    
    if crew and hasattr(crew, 'usage_metrics'):
        print(f"\nRaw Usage Metrics: {crew.usage_metrics}")

print_token_usage(result, crew)
# Out:
# ======================================================================
# CREW FINISHED - TOKEN USAGE REPORT
# ======================================================================
# Total Tokens       : 1,525
# Prompt Tokens      : 512
# Completion Tokens  : 1,013
# Successful Requests: 1
# Estimated Cost     : ~$0.0046 USD
#
# Raw Usage Metrics: total_tokens=1525 prompt_tokens=512 cached_prompt_tokens=80 completion_tokens=1013 successful_requests=1
